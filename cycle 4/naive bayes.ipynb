# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dataset = pd.read_csv('iris.csv')
X = dataset.iloc[:,:4].values
y = dataset['variety'].values
dataset.head(5)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test) 
print("Gaussian")
from sklearn.metrics import accuracy_score
accuracy =accuracy_score(y_test,y_pred)
print("Accuracy of Gaussion:",accuracy)

for (i,j) in zip(y_pred,y_test):
    if i!=j:
        print("Actual value:",i,"Predicted value:",j)
      
print("Number of mislabeled points from test data set:",(y_test != y_pred).sum())
print("")
print("Multinomial")
from sklearn.naive_bayes import MultinomialNB
classifier2 = MultinomialNB()
classifier2.fit(X_train, y_train)
y_pred = classifier2.predict(X_test) 

from sklearn.metrics import accuracy_score
accuracy =accuracy_score(y_test,y_pred)
print("Accuracy of Multinominal:",accuracy)

for (i,j) in zip(y_pred,y_test):
    if i!=j:
        print("Actual value:",i,"Predicted value:",j)
      
print("Number of mislabeled points from test data set:",(y_test != y_pred).sum())
print("")
print("Bernoulli")
from sklearn.naive_bayes import BernoulliNB
classifier2 = BernoulliNB()
classifier2.fit(X_train, y_train)
y_pred = classifier2.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy =accuracy_score(y_test,y_pred)
print("Accuracy of Bernoulli:",accuracy)
for (i,j) in zip(y_pred,y_test):
    if i!=j:
        print("Actual value:",i,"Predicted value:",j)
      
print("Number of mislabeled points from test data set:",(y_test != y_pred).sum())
print("")
print("Categorical")
from sklearn.naive_bayes import CategoricalNB
classifier2 = CategoricalNB()
classifier2.fit(X_train, y_train)
y_pred = classifier2.predict(X_test) 

from sklearn.metrics import accuracy_score
accuracy =accuracy_score(y_test,y_pred)
print("Accuracy of Categorical:",accuracy)

for (i,j) in zip(y_pred,y_test):
    if i!=j:
        print("Actual value:",i,"Predicted value:",j)
      
print("Number of mislabeled points from test data set:",(y_test != y_pred).sum())
# Out:
# Gaussian
# Accuracy of Gaussion: 0.9333333333333333
# Actual value: Versicolor Predicted value: Virginica
# Actual value: Virginica Predicted value: Versicolor
# Number of mislabeled points from test data set: 2
#
# Multinomial
# Accuracy of Multinominal: 0.9333333333333333
# Actual value: Virginica Predicted value: Versicolor
# Actual value: Virginica Predicted value: Versicolor
# Number of mislabeled points from test data set: 2
#
# Bernoulli
# Accuracy of Bernoulli: 0.3
# Actual value: Setosa Predicted value: Versicolor
# Actual value: Setosa Predicted value: Virginica
# Actual value: Setosa Predicted value: Virginica
# Actual value: Setosa Predicted value: Versicolor
# Actual value: Setosa Predicted value: Virginica
# Actual value: Setosa Predicted value: Virginica
# Actual value: Setosa Predicted value: Versicolor
# Actual value: Setosa Predicted value: Versicolor
# Actual value: Setosa Predicted value: Versicolor
# Actual value: Setosa Predicted value: Virginica
# Actual value: Setosa Predicted value: Versicolor
# Actual value: Setosa Predicted value: Virginica
# Actual value: Setosa Predicted value: Virginica
# Actual value: Setosa Predicted value: Versicolor
# Actual value: Setosa Predicted value: Versicolor
# Actual value: Setosa Predicted value: Versicolor
# Actual value: Setosa Predicted value: Virginica
# Actual value: Setosa Predicted value: Versicolor
# Actual value: Setosa Predicted value: Versicolor
# Actual value: Setosa Predicted value: Virginica
# Actual value: Setosa Predicted value: Virginica
# Number of mislabeled points from test data set: 21
#
# Categorical
# Accuracy of Categorical: 0.8333333333333334
# Actual value: Versicolor Predicted value: Virginica
# Actual value: Versicolor Predicted value: Virginica
# Actual value: Versicolor Predicted value: Virginica
# Actual value: Virginica Predicted value: Versicolor
# Actual value: Versicolor Predicted value: Virginica
# Number of mislabeled points from test data set: 5
